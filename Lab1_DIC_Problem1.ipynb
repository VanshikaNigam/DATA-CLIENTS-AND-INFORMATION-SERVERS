# %%
#Problem 1 working examples from TwitteR Vignette

# %%
library(twitteR)
library(RSQLite)

# %%
setup_twitter_oauth("wTp3cBoGCc4kPqpBxcBQLZAEx","cpGO07H3BScmbTNheewqUHmUH1Z059mO41KogT755YHqLMJxZk","772118317742055424-LtYPNm4dr2Mvq0tlVKKcz1QdRswqVtB","cKALwsJ9bliKNS22csI9lN9d56UcjgHpxjYaKjVWik250")
# Out:
# [1] "Using direct authentication"

# %%
tweets_tst <- searchTwitter('#rstats', n=50)
head(tweets_tst)
# Out:
# [[1]]
# [1] "alevergara78: RT @Rbloggers: How to perform PCA with R? https://t.co/nf0JlEufHY #rstats #DataScience"
#
# [[2]]
# [1] "Rbloggers: How to perform PCA with R? https://t.co/nf0JlEufHY #rstats #DataScience"
#
# [[3]]
# [1] "reverofun: RT @Rbloggers: Tidy Text Mining of David Bowie’s Lyrics https://t.co/KZnR0Juwop #rstats #DataScience"
#
# [[4]]
# [1] "tjmahr: #rstats the simplicity of plots/code in this post is the best argument i've seen for base graphics in a while https://t.co/2u3Z39WtbP"
#
# [[5]]
# [1] "jenstirrup: Thank you Kate @LaSystemistaria and @MangoTheCat for coming to #UKPowerBISummit to talk #RStats and #DataScience for #PowerBI!"
#
# [[6]]
# [1] "reverofun: RT @Rbloggers: Interactive plots in PCA with Factoshiny https://t.co/X7RNVcmY4M #rstats #DataScience"

# %%
tweet_test<-searchTwitter('#Trump', n=25)
head(tweet_test,10)
# Out:
# [[1]]
# [1] "disler_frank: RT @ey_frank: Damit eines klar ist: #Trump hat ein Chaos geerbt aber sicher nicht selbst verursacht ;-) https://t.co/Kf0gZ0soiX"
#
# [[2]]
# [1] "osb_fats: RT @iLEZ: The #powershake. #3dsmax #CGI #Trump https://t.co/dHF7CLOK6s"
#
# [[3]]
# [1] "FUCKHESAWAKE: RUSSIA - FAKE NEWS - low-life leakers - \"sources\" #YesterdayinaTweet #Ahhhhh #Ruuuuun #Trump #Sad"
#
# [[4]]
# [1] "gallimaufrey777: RT @SkyNews: This reporter corrected @POTUS #Trump​ at a news conference https://t.co/1iRqIZCMhI"
#
# [[5]]
# [1] "Arizonadog1: RT @DTRUMP_Fans: Did Trump Drop 2-State Policy? Mideast Experts Say Don't Be So Sure - New York Times https://t.co/z1KXehDOLl #TRUMP #Donal…"
#
# [[6]]
# [1] "Fat_mikey_Run: New drinking game! Take a shot each time #trump says \n#fakeNews."
#
# [[7]]
# [1] "oe1journale: Jan Techau: „#USA unter #Trump für #Putin ein Weihnachtsgeschenk, er kann beobachten wie Nervosität sich ausbreitet“ https://t.co/YLeNr7Ba1x"
#
# [[8]]
# ...

# %%
head(strip_retweets(tweets_tst, strip_manual=TRUE, strip_mt=TRUE))
# Out:
# [[1]]
# [1] "Rbloggers: How to perform PCA with R? https://t.co/nf0JlEufHY #rstats #DataScience"
#
# [[2]]
# [1] "tjmahr: #rstats the simplicity of plots/code in this post is the best argument i've seen for base graphics in a while https://t.co/2u3Z39WtbP"
#
# [[3]]
# [1] "jenstirrup: Thank you Kate @LaSystemistaria and @MangoTheCat for coming to #UKPowerBISummit to talk #RStats and #DataScience for #PowerBI!"
#
# [[4]]
# [1] "JanMulkens: #PowerBI and #RStats? That's easy after @LaSystemistaria's session! Thanks for sponsoring and sending her @MangoTheCat ! :)"
#
# [[5]]
# [1] "alspur: KDE #SDPFellows #rstats code review = best way to start a Friday morning!"
#
# [[6]]
# [1] "abresler: I think I figured out the perfect @hrbrmstr sports analogy; he is the @Money23Green of #rstats!! Checkout his stuff!\nhttps://t.co/15H8hQvABN"

# %%
crantastic <- getUser('crantastic')
crantastic$getDescription()
# Out:
# [1] "I like some things, and I dislike everything else."

# %%
abresler<-getUser('abresler')
abresler$getDescription()
# Out:
# [1] "The stop-watch of history is running. The race is on . ."

# %%
crantastic$getFollowersCount()
# Out:
# [1] 32

# %%
abresler$getFollowersCount()
# Out:
# [1] 1827

# %%
crantastic$getFriends(n=10)
# Out:
# $`35985504`
# [1] "MisElizaJane"
#
# $`90472293`
# [1] "emtothea"
#
# $`30987732`
# [1] "MelanieScrofano"
#
# $`4709232802`
# [1] "WynonnaEarp"
#
# $`263914081`
# [1] "DominiqueP_C"
#
# $`389898091`
# [1] "KatBarrell"
#
# $`2155365456`
# [1] "imrosemciver"
#
# $`23787990`
# [1] "anamatics"
#
# $`2657140026`
# [1] "SilasUniversity"

# %%
crantastic$getFavorites(n=6)
# Out:
# [[1]]
# [1] "erictcarrasco: That \"Black lung\" line was a @Chy_Leigh joke. Loved it so much we made her keep saying it. #Supergirl #SupergirlLives #Sanvers"
#
# [[2]]
# [1] "MelanieScrofano: I shall be INSUFFERABLE when the @WynonnaEarp comic I'm co-writing with @BeauSmithRanch comes out. \"The Earp Sister… https://t.co/h0Q6XrE1dV"
#
# [[3]]
# [1] "katevoegele: just casually throwing my white gold hoops in the ring to play #GretchenWieners in this https://t.co/0l9FSGjTuD"
#
# [[4]]
# [1] "boglesthemind: Here we go, QSO - female writer, female director, female producer, female editor, female lead, female first ad #PersonOfInterest #toofemale"
#
# [[5]]
# [1] "ohnikkers: @keithkurson naw they did two shows in london and i went to both.  i made hannah fall in love with the scottish accent tho so NEXT TIME"
#
# [[6]]
# [1] "mrcartaire: @karmytho Absolutely not.  Amy is definitely not straight."

# %%
df_tst <- twListToDF(tweets_tst)

# %%
head(df_tst)
# Out:
#   text
# 1 RT @Rbloggers: How to perform PCA with R? https://t.co/nf0JlEufHY #rstats #DataScience
# 2 How to perform PCA with R? https://t.co/nf0JlEufHY #rstats #DataScience
# 3 RT @Rbloggers: Tidy Text Mining of David Bowie’s Lyrics https://t.co/KZnR0Juwop #rstats #DataScience
# 4 #rstats the simplicity of plots/code in this post is the best argument i've seen for base graphics in a while https://t.co/2u3Z39WtbP
# 5 Thank you Kate @LaSystemistaria and @MangoTheCat for coming to #UKPowerBISummit to talk #RStats and #DataScience for #PowerBI!
# 6 RT @Rbloggers: Interactive plots in PCA with Factoshiny https://t.co/X7RNVcmY4M #rstats #DataScience
#   favorited favoriteCount replyToSN created             truncated replyToSID
# 1 FALSE     0             NA        2017-02-17 14:57:03 FALSE     NA
# 2 FALSE     1             NA        2017-02-17 14:56:41 FALSE     NA
# 3 FALSE     0             NA        2017-02-17 14:54:10 FALSE     NA
# ...

# %%
sql_lite_file = tempfile()
register_sqlite_backend(sql_lite_file)
store_tweets_db(tweets_tst)
# Out:
# [1] TRUE

# %%
from_db_tst = load_tweets_db()
head(from_db_tst)
# Out:
# [[1]]
# [1] "alevergara78: RT @Rbloggers: How to perform PCA with R? https://t.co/nf0JlEufHY #rstats #DataScience"
#
# [[2]]
# [1] "Rbloggers: How to perform PCA with R? https://t.co/nf0JlEufHY #rstats #DataScience"
#
# [[3]]
# [1] "reverofun: RT @Rbloggers: Tidy Text Mining of David Bowie’s Lyrics https://t.co/KZnR0Juwop #rstats #DataScience"
#
# [[4]]
# [1] "tjmahr: #rstats the simplicity of plots/code in this post is the best argument i've seen for base graphics in a while https://t.co/2u3Z39WtbP"
#
# [[5]]
# [1] "jenstirrup: Thank you Kate @LaSystemistaria and @MangoTheCat for coming to #UKPowerBISummit to talk #RStats and #DataScience for #PowerBI!"
#
# [[6]]
# [1] "reverofun: RT @Rbloggers: Interactive plots in PCA with Factoshiny https://t.co/X7RNVcmY4M #rstats #DataScience"

# %%
cran_tweets <- userTimeline('cranatic')
cran_tweets[1:5]
jen_tweets <- userTimeline('jenstirrup')
jen_tweets[1:5]
# Out:
# [[1]]
# [1] "cranatic: Update: Bchron, BoolNet, caribou, CePa, fmri, HTSCluster, isa2, lessR, lgcp, spatstat. http://t.co/skyrajMA #rstats"
#
# [[2]]
# [1] "cranatic: New: extrafont, extrafontdb, Rttf2pt1, x12GUI. http://t.co/skyrajMA #rstats"
#
# [[3]]
# [1] "cranatic: Update: drc, RcmdrPlugin.survival, rrcov, spls. http://t.co/eEoXNifB #rstats"
#
# [[4]]
# [1] "cranatic: New: hzar. http://t.co/eEoXNifB #rstats"
#
# [[5]]
# [1] "cranatic: Update: directlabels, forensim, gdata, gWidgetstcltk, gWidgetsWWW, harvestr, rrlda, Rz, Sim.DiffProc, ... http://t.co/9JEe7K91 #rstats"
# [[1]]
# [1] "jenstirrup: Summary of the latest #dataviz news! https://t.co/V1S8VoNShy - top stories by @Beezel_Bug, @PyDataBA, @Radioactive3D"
#
# [[2]]
# [1] "jenstirrup: Thank you Kate @LaSystemistaria and @MangoTheCat for coming to #UKPowerBISummit to talk #RStats and #DataScience for #PowerBI!"
#
# [[3]]
# ...

# %%
cran_tweets_large <- userTimeline('cranatic', n=100)
length(cran_tweets_large)
# Out:
# [1] 100

# %%
avail_trends = availableTrendLocations()
tail(avail_trends)
# Out:
#     name        country      woeid
# 462 Venezuela   Venezuela    23424982
# 463 Vietnam     Vietnam      23424984
# 464 Petaling    Malaysia     56013632
# 465 Hulu Langat Malaysia     56013645
# 466 Ahsa        Saudi Arabia 56120136
# 467 Okayama     Japan        90036018

# %%
trends = getTrends(2367105)
head(trends)
# Out:
#   name                  url
# 1 Lowell                http://twitter.com/search?q=Lowell
# 2 #TrumpPressConference http://twitter.com/search?q=%23TrumpPressConference
# 3 #DayWithoutImmigrants http://twitter.com/search?q=%23DayWithoutImmigrants
# 4 #AAASmtg              http://twitter.com/search?q=%23AAASmtg
# 5 Marcus Smart          http://twitter.com/search?q=%22Marcus+Smart%22
# 6 #PresidentialTVShows  http://twitter.com/search?q=%23PresidentialTVShows
#   query                   woeid
# 1 Lowell                  2367105
# 2 %23TrumpPressConference 2367105
# 3 %23DayWithoutImmigrants 2367105
# 4 %23AAASmtg              2367105
# 5 %22Marcus+Smart%22      2367105
# 6 %23PresidentialTVShows  2367105

# %%
trends = getTrends(56013632)
head(trends)
# Out:
#   name
# 1 Malaysia
# 2 China
# 3 JAWI
# 4 #KimJongNam
# 5 #HBDPrinceSivaKarthikeyan
# 6 Chatime
#   url
# 1 http://twitter.com/search?q=Malaysia
# 2 http://twitter.com/search?q=China
# 3 http://twitter.com/search?q=JAWI
# 4 http://twitter.com/search?q=%23KimJongNam
# 5 http://twitter.com/search?q=%23HBDPrinceSivaKarthikeyan
# 6 http://twitter.com/search?q=Chatime
#   query                       woeid
# 1 Malaysia                    56013632
# 2 China                       56013632
# 3 JAWI                        56013632
# 4 %23KimJongNam               56013632
# 5 %23HBDPrinceSivaKarthikeyan 56013632
# 6 Chatime                     56013632

# %%
r_tweets <- searchTwitter("#rstats", n=300)

# %%
sources <- sapply(r_tweets, function(x) x$getStatusSource())
sources <- gsub("</a>", "", sources)
sources <- strsplit(sources, ">")
sources <- sapply(sources, function(x) ifelse(length(x) > 1, x[2], x[1]))

# %%
source_table = table(sources)
show(source_table)
pie(source_table[source_table > 10])
# Out:
# sources
#                AutoPost Viper IT                           Buffer
#                                2                                4
#                     Connector394                 CRANberries Feed
#                                1                               12
#                    DailyRpackage                  Datascience Cat
#                                1                                1
#                  dettonville.org           Dream Weaver Diaries 1
#                                1                                1
#             EClassHosting finder                        Hootsuite
#                                1                                4
#                            IFTTT                         LinkedIn
#                                3                                1
#           manifattura 4.0 (beta)                           mlbot1
#                                1                                1
# ...

# %%
r_tweets_india <- searchTwitter("#india", n=300)

# %%
sources1 <- sapply(r_tweets_india, function(x) x$getStatusSource())
sources1 <- gsub("</a>", "", sources1)
sources1 <- strsplit(sources1, ">")
sources1 <- sapply(sources1, function(x) ifelse(length(x) > 1, x[2], x[1]))

# %%
source_table = table(sources1)
show(source_table)
pie(source_table[source_table > 10])
# Out:
# sources1
#                  PixelTweeter         advertisements promos
#                             1                             1
#                      AmendPCA                       Arduino
#                             1                             2
#                  BeingExample                        Botize
#                             1                             1
#                        Buffer                       dlvr.it
#                             2                            20
#                   Dropial App                        empowr
#                             1                             1
#             Evenflow Automate                      Facebook
#                             1                            11
#          Following_The_People                        Google
#                             3                             6
# HealingHeatTherapySaunaTweets                     Hootsuite
# ...
